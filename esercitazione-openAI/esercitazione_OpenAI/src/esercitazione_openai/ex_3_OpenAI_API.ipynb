# %% [markdown]
# # Esercizio 3
#
# **Traccia:** Crea un prompt che riassuma un articolo di notizie in un singolo paragrafo di al massimo 255 caratteri.
#
# **Obiettivo:** Prendere un testo lungo e condensarlo nei punti essenziali.

# %%
# %pip install python-dotenv openai

# %%
# TODO Inizializza il client di Open AI
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv('.env')

client = OpenAI()

# %%
input_text = input("Enter text: ")

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Sei un esperto di riassunti. Quando ricevi un testo, crea un riassunto di massimo 255 caratteri, manitieni le informazioni principali. Usa uno stile neutro."},
        {"role": "user", "content": input_text}
    ],
)

print(completion.choices[0].message.content)
# Out:
# Scoperta una nuova specie di rana nelle foreste pluviali dell'Amazzonia, caratterizzata da un colore verde brillante e piccole dimensioni. Questa scoperta può fornire informazioni sulla biodiversità della regione e sottolinea l'importanza della conservazione degli habitat minacciati dalla deforestazione.
